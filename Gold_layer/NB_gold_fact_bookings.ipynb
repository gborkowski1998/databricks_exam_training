# %%
# %run ../Common_functions/NB_common_functions

# %%
target_catalog_name = dbutils.widgets.get("catalog_name")
silver_schema = dbutils.widgets.get("silver_schema")
gold_schema = dbutils.widgets.get("gold_schema")
columns = ["booking_id", "check_in", "check_out", "total_amount", "property_id", "guest_id"]
target_table_name = "fact_bookings"
source_name = dbutils.widgets.get("source_name")

# %%
load_to_gold_without_joins(target_catalog_name=target_catalog_name, silver_schema=silver_schema, gold_schema=gold_schema, columns=columns, target_table_name=target_table_name, source_name=source_name)
