# %%
main_df = spark.table("workspace.silver.wanderbricks_main")

fact_bookings_df = main_df.select("booking_id", "check_in", "check_out", "total_amount", "property_id", "user_id")

fact_bookings_df.write.mode("overwrite").saveAsTable("workspace.gold.wanderbricks_fact_bookings")
