# %%
# %run ../Common_functions/NB_common_functions

# %%
load_to_gold_without_joins(columns=["booking_id", "check_in", "check_out", "total_amount", "property_id", "guest_id"], target_table_name="fact_bookings")
