# %%
main_df = spark.table("workspace.silver.wanderbricks_main")

dim_hotels_df = main_df.select("property_id", "Hotel_name")

dim_hotels_df.write.mode("overwrite").saveAsTable("workspace.gold.wanderbricks_dim_hotels")
