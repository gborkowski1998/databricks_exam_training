# %%
# %run ../Batch_source/NB_load_batch_data

# %%
source_catalog_name = 'samples'
target_catalog_name = dbutils.widgets.get("catalog_name")
bronze_schema = dbutils.widgets.get("bronze_schema")
source_name = dbutils.widgets.get("source_name")
table_name = 'properties'

# %%
load_batch_data(source_catalog_name=source_catalog_name, target_catalog_name=target_catalog_name, bronze_schema=bronze_schema, source_name=source_name, table_name=table_name)
