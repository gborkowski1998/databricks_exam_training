# %%
# %run ../Common_functions/NB_common_functions

# %%
source_catalog_name = 'samples'
target_catalog_name = dbutils.widgets.get("catalog_name")
bronze_schema = dbutils.widgets.get("bronze_schema")
source_name = dbutils.widgets.get("source_name")
table_name = 'bookings'

# %%
load_bronze_streaming_data(source_catalog_name=source_catalog_name, source_name=source_name, target_catalog_name=target_catalog_name, bronze_schema=bronze_schema, table_name=table_name)
